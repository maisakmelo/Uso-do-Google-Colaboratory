# %% [markdown]
# # Como ler, alterar e salvar arquivos pelo Google Colaboratory

# %% [markdown]
# Neste arquivo você pode ler, alterar e salvar um arquivo .csv que está numa pasta do GoogleDrive utilizando o Google Colaboratory

# %% [markdown]
# ### Para isto:
# 1. crie um arquivo .ipynb;
# 2. abra-o utilizando o Google Colaboratory.

# %% [markdown]
# Após abrir o arquivo .ipynb pelo Google Colaboratory, você precisa trazer sua pasta onde estão os arquivos para o
# Google Colaboratory.
#
# Use o comando abaixo:

# %%
from google.colab import drive

drive.mount('/content/gdrive')

# %% [markdown]
# Ao executar o comando abaixo, irá aparecer um link que irá te direcionar para autorizar o uso da sua conta do gmail. Clique em permitir,
# copie e cole o link que dá acesso a sua conta do gmail. Cole o link no espaço em branco e dê enter.

# %% [markdown]
# Pronto! Agora você pode visualizar sua pasta do Google Drive no lado esquerdo da tela do Google Colaboratory.

# %% [markdown]
# Para ler e salvar os arquivos que estão nesta pasta, é necessário informar o caminho dela.

# %% [markdown]
# Inicialmente o comando **import sys** traz toda a pasta onde estão os arquivos .py. Depois, para cada arquivo .txt, .xlsx, .csv, etc, o caminho deverá ser informado individualmente.

# %% [markdown]
# Para obter o caminho da pasta, clique com o botão direito do mouse em copiar caminho. Cole o endereço do caminho usando o comando abaixo:

# %%
import sys
sys.path.insert(1, '/content/gdrive/My Drive/Doutorado/VALENDO/VALENDO_SO_SUCESSO')

# %% [markdown]
# Agora é possível acessar todas as funções e arquivos que estão nesta pasta.

# %% [markdown]
# Vamos ler o arquivo com o preço de fechamento do Ibovespa no período de 2016 a 2018.
# Calcular o retorno desses ativos para esse período.
# Salvar os retornos.

# %%
import RETORNO as ret

# %%
retornos = ret.retorno()
df_ret = round(df_ret,4)

# %%
ValoresMMV500 =  pd.read_csv('/content/gdrive/My Drive/Doutorado/VALENDO/VALENDO_SO_SUCESSO/Valores_M_M_VarianciaTESTE.csv', sep = ';', index_col = 0)
